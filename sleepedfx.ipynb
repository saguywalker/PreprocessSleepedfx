# %%
import numpy as np
import pandas as pd
import mne
from mne.io import read_raw_edf, concatenate_raws
from mne import Epochs, pick_types, find_events
import glob
import dhedfreader
import os
from datetime import datetime

# %%
ann2label = {
    "Sleep stage W": 0,
    "Sleep stage 1": 1,
    "Sleep stage 2": 2,
    "Sleep stage 3": 3,
    "Sleep stage 4": 3,
    "Sleep stage R": 4,
    "Sleep stage ?": 5,
    "Movement time": 5
}

EPOCH_SEC_SIZE = 30

picks = [i for i in range(6)]

num_sample = 25
num_sub = 10
srate = 100

# %%
def get_files_name(file_type):
    psg_fnames = glob.glob(os.path.join(file_type, "*PSG.edf"))
    ann_fnames = glob.glob(os.path.join(file_type, "*Hypnogram.edf"))
    psg_fnames.sort()
    ann_fnames.sort()
    psg_fnames = np.asarray(psg_fnames).reshape(-1 ,1)
    ann_fnames = np.asarray(ann_fnames).reshape(-1, 1)
    assert len(psg_fnames) == len(ann_fnames)
    
    return np.concatenate((psg_fnames, ann_fnames), axis=1)

# %%
def read_edf(fnames):
    raw = read_raw_edf(fnames[0], preload=False, stim_channel=None)
    srate = int(raw.info['sfreq'])
    step = EPOCH_SEC_SIZE*srate
    
    data = raw.get_data().T[:,:2]
    
    data = data[:data.shape[0]//step*step].reshape(-1, step, 2)
    anno = get_annotations(fnames[1])
    last_event = int((anno[-1][0] + anno[-1][1])/ 30)
    data = data[:last_event]
    labels = get_labels(anno, srate, data.shape[0])
    data, labels = remove_bad_labels(data, labels)
    start_idx, end_idx = pick_idx(labels)
    
    if start_idx < 60:
        return (data[:end_idx + 60], labels[:end_idx + 60])      
    return (data[start_idx - 60:end_idx + 60], labels[start_idx - 60:end_idx + 60])

# %%
def get_annotations(fnames):
    with open(fnames, 'r', encoding='utf8') as f:
        reader_ann = dhedfreader.BaseEDFReader(f)
        reader_ann.read_header()
        h_ann = reader_ann.header
        _, _, anno = zip(*reader_ann.records())
    return anno[0]

# %%
def get_labels(anno, srate, size):
    step = srate*EPOCH_SEC_SIZE
    labels = np.full((int(size)), -1)
    ann = np.array([[a[0], a[1], ann2label[a[2]]] for a in anno], dtype=int)
    for a in ann:
        labels[int(a[0]/30):int((a[0]+a[1])/30)] = a[2]
    return labels

# %%
def remove_bad_labels(data, labels):
    bad_idx = [i for i, x in enumerate(labels) if x == 5 or x == -1]
    x = np.delete(data, bad_idx, axis=0)
    y = np.delete(labels, bad_idx, axis=0)
    return x, y

# %%
def pick_idx(labels):
    start_idx = next(i for i, x in enumerate(labels) if x == 1)
    end_idx = next(i for i, x in reversed(list(enumerate(labels))) if x != 0) + 1

    return start_idx, end_idx

# %%
def pick_sub(data, labels, num_sub):
    size = data.shape[0]//num_sub*num_sub
    data = data[:size].reshape(num_sub, -1, EPOCH_SEC_SIZE*srate, data.shape[2])
    labels = labels[:size].reshape(num_sub, -1)
    
    return data, labels

# %%
def pick_sample(data, labels, num_sample):
    x = [d[:num_sample] for d in data]
    y = [l[:num_sample] for l in labels]
    
    return np.array(x).reshape(-1, EPOCH_SEC_SIZE*srate, data.shape[3]), np.asarray(y, dtype=int).reshape(-1)

# %%
def concate_np(rawx, rawy):
    x = rawx[0]
    for r in rawx[1:]:
        x = np.concatenate((x, r), axis=0)
    
    y = rawy[0]
    for r in rawy[1:]:
        y = np.concatenate((y, r), axis=0)
        
    return x, y

# %%
files_name_sc = get_files_name("SC")
files_name_st = get_files_name("ST")

# %%
data_sc, labels_sc = zip(*[read_edf(f) for f in files_name_sc])
data_st, labels_st = zip(*[read_edf(f) for f in files_name_st])
# Out:
# Extracting EDF parameters from SC\SC4001E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4002E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4011E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4012E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4021E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4022E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4031E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4032E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4041E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4042E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4051E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4052E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4061E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4062E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4071E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4072E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4081E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4082E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4091E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4092E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4101E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4102E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4111E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4112E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4121E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4122E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4131E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4141E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4142E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4151E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4152E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4161E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4162E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4171E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4172E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4181E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4182E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4191E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from SC\SC4192E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7011J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7022J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7041J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7052J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7061J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7071J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7082J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7092J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7101J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7112J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7121J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7132J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7141J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7151J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7162J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7171J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7182J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7192J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7201J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7212J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7221J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ST\ST7241J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
x_sc, y_sc = concate_np(data_sc, labels_sc)
x_st, y_st = concate_np(data_st, labels_st)

print(x_sc.shape, y_sc.shape)
print(x_st.shape, y_st.shape)
# Out:
# (42229, 3000, 2) (42229,)
# (21202, 3000, 2) (21202,)

# %%
pid_st = np.hstack([np.full(len(data_st[i]), f) for i, f in enumerate(files_name_st[:,0])])
pid_st = pid_st.reshape(-1)

pid_sc = np.hstack([np.full(len(data_sc[i]), f) for i, f in enumerate(files_name_sc[:,0])])
pid_sc = pid_sc.reshape(-1)

# %%
#data_sub_sc, labels_sub_sc = zip(*[pick_sub(x, labels_sc[i], num_sub) for i, x in enumerate(data_sc)])
#data_sub_st, labels_sub_st = zip(*[pick_sub(x, labels_st[i], num_sub) for i, x in enumerate(data_st)])

# %%
#x_sample_sc, y_sample_sc = zip(*[pick_sample(x, labels_sub_sc[i], num_sample) for i, x in enumerate(data_sub_sc)])
#x_sample_st, y_sample_st = zip(*[pick_sample(x, labels_sub_st[i], num_sample) for i, x in enumerate(data_sub_st)])

# %%
"""x_st = np.asarray(x_sample_st)
y_st = np.asarray(y_sample_st, dtype=int).reshape(-1)
x_st = x_st.reshape(-1, x_st.shape[2], x_st.shape[3])

pid_st = np.array([np.full((num_sample*num_sub), f) for f in files_name_st[:,0]])
pid_st = pid_st.reshape(-1)

print(x_st.shape, y_st.shape, pid_st.shape)"""
# Out:
# (5500, 3000, 2) (5500,) (5500,)

# %%
np.savez("ST_all.npz", X=x_st, sleep_stages=y_st, pid=pid_st)
np.savez("SC_all.npz", X=x_sc, sleep_stages=y_sc, pid=pid_sc)
